# %% [markdown]
# <a href="https://colab.research.google.com/github/BISH0808/Algorithms/blob/main/Notes_from_UlbiTV_video/Selection_sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Selection sort (Сортировка выбором)

# %% [markdown]
# #Суть

# %% [markdown]
# Суть сортировки выбором: есть массив неупорядоченных элементов.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Мы в цикле находим минимальный. В данном случае это единица

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Потом меняем местами с первым элементом.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Затем опять пробегаемся по массиву и находим минимальный элемент, но меняем его со вторым элементом, затем с третьим, четвертым и так далее, пока не будет отсортирован массив.

# %% [markdown]
# #Решение

# %%
const arr = [0, 3, 2, 5, 6, 8, 1, 9, 4, 2, 1, 2, 9, 6, 4, 1, 7, -1, -5, 23, 6, 2, 35, 6, 3, 32] // [0, 1, 1, 2, 3........]
let count = 0

function selectionSort(array) {
    for (let i = 0; i < array.length; i++) {
      let indexMin = i;
      for (let j = i + 1; j < array.length; j++) {
        if (array[j] < array[indexMin]) {
          indexMin = j;
        }
        count += 1;
      }
      let tmp = array[i];
      array[i] = array[indexMin];
      array[indexMin] = tmp;
    }
    return array;
  }
  
  console.log(selectionSort(arr));
  console.log(count);

# %% [markdown]
# **Ответ:**
#
#
# [
#   -5, -1, 0, 1, 1, 1, 2,  2,
#    2,  2, 3, 3, 4, 4, 5,  6,
#    6,  6, 6, 7, 8, 9, 9, 23,
#   32, 35
# ]
#
#
# 325

# %% [markdown]
# #Сложность алгоритма

# %% [markdown]
# Сложность этого алгоритма должна быть O(n*n).
# Но 325 не равняется 26^2.
# Получается, что внешний цикл проходится полностью по всему массиву, а во внутреннем мы каждый раз на единицу сдвигаемся.
# Получается, что перед n^2 стоит коэффициент.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Но вот эти коэффициенты в оценке сложности алгоритма никогда не участвуют, оставляем только n^2.**
